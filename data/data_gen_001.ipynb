# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %%
num_x1 = 50
num_x2 = 50
num_x3 = 10

# x1 = np.linspace(0,4*np.pi,num_x1)
# x2 = np.linspace(0,4*np.pi,num_x2)

x1 = 4*np.pi*(np.random.uniform(size=num_x1)-0.5)
x2 = 4*np.pi*(np.random.uniform(size=num_x2)-0.5)
x3 = (np.random.uniform(size=num_x3)-0.5)

xx1,xx2,xx3 = np.meshgrid(x1,x2,x3)

y1 = np.sin(xx1)+np.cos(xx2)+0.2*(np.random.rand(num_x1,num_x2,num_x3)-0.5)
y2 = np.sin(xx1)+np.cos(xx2)+xx3+0.2*(np.random.rand(num_x1,num_x2,num_x3)-0.5)

data_input = np.array([xx1, xx2,xx3]).reshape(3, -1).T
data_output = np.array([y1,y2]).reshape(2, -1).T

df_input = pd.DataFrame(data_input, columns=['x1','x2','x3'])
df_output = pd.DataFrame(data_output, columns=['y1','y2'])

df_input.to_csv('data_input_001.csv')
df_output.to_csv('data_output_001.csv')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xx1,xx3,y2,
           edgecolor = 'black',
           alpha = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
display(df_input)
display(df_output)
# Out:
#              x1        x2        x3
# 0      5.211856  3.849401 -0.183180
# 1      5.211856  3.849401  0.046188
# 2      5.211856  3.849401 -0.049773
# 3      5.211856  3.849401 -0.381295
# 4      5.211856  3.849401 -0.349120
# ...         ...       ...       ...
# 24995 -5.575664 -0.809402  0.022162
# 24996 -5.575664 -0.809402 -0.343465
# 24997 -5.575664 -0.809402  0.464218
# 24998 -5.575664 -0.809402 -0.308300
# 24999 -5.575664 -0.809402 -0.201793
#
# [25000 rows x 3 columns]
#              y1        y2
# 0     -1.638082 -1.801888
# 1     -1.599566 -1.592669
# 2     -1.541234 -1.780504
# 3     -1.650795 -1.928039
# 4     -1.732432 -1.960724
# ...         ...       ...
# 24995  1.258734  1.265430
# 24996  1.415776  0.974667
# 24997  1.307663  1.817155
# 24998  1.266246  1.096351
# 24999  1.301984  1.191114
#
# [25000 rows x 2 columns]
