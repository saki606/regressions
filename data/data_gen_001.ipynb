# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %%
num = 50

x = np.linspace(0,4*np.pi,num)
y = np.linspace(0,4*np.pi,num)

xx,yy = np.meshgrid(x,y)

z = np.sin(xx)+np.cos(yy)+0.2*(np.random.rand(num,num)-0.5)

data = np.array([xx, yy, z]).reshape(3, -1).T
df = pd.DataFrame(data, columns=['x','y','z'])

df.to_csv('data_001.csv')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xx,yy,z,
           edgecolor = 'black',
           alpha = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
df
# Out:
#               x          y         z
# 0      0.000000   0.000000  0.900821
# 1      0.256457   0.000000  1.273228
# 2      0.512913   0.000000  1.467639
# 3      0.769370   0.000000  1.614512
# 4      1.025826   0.000000  1.873247
# ...         ...        ...       ...
# 2495  11.540544  12.566371  0.051119
# 2496  11.797001  12.566371  0.255046
# 2497  12.053458  12.566371  0.503383
# 2498  12.309914  12.566371  0.739053
# 2499  12.566371  12.566371  0.942409
#
# [2500 rows x 3 columns]
